# %% [markdown]
# > lesson 3 and lesson 5

# %%
len([1,3,5,22,1,55,67,887])
[1,44,]+[22,11,30,58]
["Hello Aiubians!"]*3
192 in [33,100,192,54,88]

# %%
A=['hello','Hello','HELLO']
A[1]
A.pop(-1)

# %%
A[1:2]=['to','AIUB']
A

# %%
A[-1]

# %%
matrixM= [[55,12,89,22],[45,556,211,88]]
matrixM[0]
matrixM[0][1]

# %%
A.append('Life')

# %%
A.pop(-1)
A

# %%
A.reverse()

# %%
A.reverse()
A

# %%
del A[0]
A

# %% [markdown]
# > operations

# %%
x2={'food':2 ,'tyres':4 ,}
x2['tyres']

# %%
x2
len(x2)

# %%
'food' in x2
x2.keys()

# %%
x2['food']=['rice','chicken','lentil soup']
x2

# %%
del x2['tyres']
x2

# %%
x2.values()
x2.items()

# %%
x2.get('beef')
x2

# %%
x1={'tea': 3, 'coffe':5}

# %%
x1

# %%
x2.update(x1)
x2

# %%
x2.pop('tea')
x2

# %%
table={'language1':'pyhton', 
      'language2':'Java',
      'language3':'C'}

# %%
language = 'language2'
creator = table[language]
creator

# %%
Matrix01={}
Matrix01[(190,54)]=90

# %%
Matrix01[(77,3)]=10

# %%
M=190;N=54

# %%
Matrix01[(M,N)]
Matrix01
# Out:
# {(190, 54): 90, (77, 3): 10}

# %%
Matrix01[(1,5,7)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-298968186cb2> in <module>
# ----> 1 Matrix01[(1,5,7)]
#
# KeyError: (1, 5, 7)

# %%
if (1,5,7) in Matrix01.keys():
    print (Matrix01[(1,5,7)])
else:
    print (0)
# Out:
# 0

# %%
try:
    print (Matrix01[(1,5,7)])
except KeyError:
    print (0)
# Out:
# 0

# %%
a = 67
b = 208
if b > a:
  print("b is bigger than a")
else:
  print("b is smaller a")
# Out:
# b is bigger than a

# %% [markdown]
# > chapter 5

# %%
while True:
    reply=input('Enter text:')
    if reply=='Bye':
        print (reply.upper())
        break

# %%
while True:
  reply = input('Enter text:')
  if reply == 'halt':
        print(reply)
        break
# Out:
# Enter text:halt
# halt

# %%
while True:
    reply = input("Enter Text:")
    if reply == 'halt':
        print ('Thanks')
        break
# Out:
# Enter Text:halt
# Thanks

# %%
while True:
    reply = input('Enter text: ')
    if reply == 'stop':
        break
    else:
        print(int (reply) **2)
# Out:
# Enter text: 4
# 16
# Enter text: stop

# %%
while True:
    reply = input('Enter text:')
    if reply == 'halt':
        break
    elif not reply.isdigit():
        print ('THANKS!' * 5)
    else:
        print (int(reply) ** 3)
print ('GOOD DAY')
# Out:
# Enter text:ngfgn
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-68a44f24c4e2> in <module>
#       4         break
#       5     elif not reply.isdigit():
# ----> 6         print ('THANKS!' ** 5)
#       7     else:
#       8         print (int(reply) ** 3)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
 M = 'dakdjagd'
 N = '11'
M.isdigit( ), N.isdigit( )
(True, False)

# %%
while True:
    reply = input('Enter text:')
    if reply == 'halt':
        break
    elif not reply.isdigit():
        print ('Thanks!' * 5)
    else:
        num = int(reply)
        if num < 10:
            print ('Small')
        else:
            print (num ** 1)
print ('GOOD DAY')
# Out:
# Enter text:hdhd
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-bb4780bf2b70> in <module>
#       4         break
#       5     elif not reply.isdigit():
# ----> 6         print ('Thanks!' ** 5)
#       7     else:
#       8         num = int(reply)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
while True:
    reply = input('Enter text:')
    if reply == 'halt':
        break
    elif not reply.isdigit():
        print ('Thanks!' * 5)
    else:
        num = int(reply)
        if num > 100:
            print ('Large')
        else:
            print (num ** 1)
        print ('GOOD DAY')
# Out:
# Enter text:bdf
# Thanks!Thanks!Thanks!Thanks!Thanks!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /opt/conda/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     806         try:
# --> 807             msg_list = socket.recv_multipart(mode, copy=copy)
#     808         except zmq.ZMQError as e:
#
# /opt/conda/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
# ...
